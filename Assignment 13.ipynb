# %% [markdown]
# # 1. What advantages do Excel spreadsheets have over CSV spreadsheets?

# %% [markdown]
# Ans:-
#
#     In Excel, spreadsheets can have values of data types other than strings. cells can have different forts, sizes,
#
#     or colour setting. Cells can have varying widths and heights, adjacent cells can be merged.
#
#     you can embed images and charts.

# %% [markdown]
# # 2.What do you pass to csv.reader() and csv.writer() to create reader and writer objects?

# %% [markdown]
# Ans:-
#
#     You pass a file object, obtained from a call to open().

# %% [markdown]
# # 3. What modes do File objects for reader and writer objects need to be opened in?

# %% [markdown]
# Ans:-
#
#     File objects need to be opened in read-binary('rb') for Reader object.
#
#     and
#
#     write-binary('wb') for writer objects.

# %% [markdown]
# # 4. What method takes a list argument and writes it to a CSV file?

# %% [markdown]
# Ans:-
#
#     The writerow() method.

# %% [markdown]
# # 5. What do the keyword arguments delimiter and line terminator do?

# %% [markdown]
# Ans:-
#
#     The delimiter argument changes the string used to seperate cells in a row.
#
#     The lineterminator argument changes the string used to seperate rows.

# %% [markdown]
# # 6. What function takes a string of JSON data and returns a Python data structure?

# %% [markdown]
# Ans:-
#
#     json.loads() function takes a string jSON data and returns a Python data structure.

# %% [markdown]
# # 7. What function takes a Python data structure and returns a string of JSON data?

# %% [markdown]
# Ans:-
#
#     json.dumps() takes a Python data structure and returns a string of JSON data.
