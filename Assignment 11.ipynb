# %% [markdown]
# # 1. Create an assert statement that throws an AssertionError if the variable spam is a negative integer.

# %%
spam = int(input())
assert spam >= 0, 'The spam variable is less than 0.'
# Out:
# -1
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13248/2046070304.py in <module>
#       1 spam = int(input())
# ----> 2 assert spam >= 0, 'The spam variable is less than 0.'
#
# AssertionError: The spam variable is less than 0.

# %% [markdown]
# # 2. Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain strings that are the same as each other, even if their cases are different (that is, 'hello' and 'hello' are considered the same, and 'goodbye' and 'GOODbye' are also considered the same).

# %%
eggs = input()
bacon = input()
assert eggs.lower() != bacon.lower(), 'The eggs and bacon variables are same!'
assert eggs.upper() != bacon.upper(),'The eggs and bacon variable are the same'
# Out:
# HELLO
# hello
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13248/2544293544.py in <module>
#       1 eggs = input()
#       2 bacon = input()
# ----> 3 assert eggs.lower() != bacon.lower(), 'The eggs and bacon variables are same!'
#       4 assert eggs.upper() != bacon.upper(),'The eggs and bacon variable are the same'
#
# AssertionError: The eggs and bacon variables are same!

# %% [markdown]
# # 3. Create an assert statement that throws an AssertionError every time.

# %%
assert False, 'This assertion throws an error every time'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13248/821878126.py in <module>
# ----> 1 assert False, 'This assertion throws an error every time'
#
# AssertionError: This assertion throws an error every time

# %% [markdown]
# # 4. What are the two lines that must be present in your software in order to call logging.debug()?

# %% [markdown]
# Ans:
#
#     To call logging.debug(), you must have these two lines at the starta of your program.
#     The two lines are as follows:

# %%
import logging 
logging.basicConfig(level ='logging.DEBUG', format = '%(asctime)s, %(levelname)s, %(message)s')

# %% [markdown]
# # 5. What are the two lines that your program must have in order to have logging.debug() send a logging message to a file named programLog.txt?

# %% [markdown]
# Ans:
#
#     To send logging messages to a file named programLog.txt with logging.debug(), you must need to add these two lines at
#     start of your program.
#     which are as follows:

# %%
import logging as lg
lg.basicConfig(filename = 'programLog.txt', level = 'lg.DEBUG', format = '%(asctime)s, %(levelname)s, %(messages)s')

# %% [markdown]
# # 6. What are the five levels of logging?

# %% [markdown]
# Ans:
#
#     The five level are as follows;
#
#     1) Not set - 0
#     2) DEBUG - 10
#     3) INFO  - 20
#     4) WARNING - 30
#     5) ERROR   - 40
#     6) CRITICAL - 50.

# %% [markdown]
# # 7. What line of code would you add to your software to disable all logging messages?

# %% [markdown]
# Ans:
#
#     logging.disable(logging.critical)

# %% [markdown]
# # 8.Why is using logging messages better than using print() to display the same message?

# %% [markdown]
# Ans:
#
#     To create a logging messages to disable logging messages without removing the logging function calls.
#
#     logging messages provides a timestamp.

# %% [markdown]
# # 9. What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?

# %% [markdown]
# Ans:
#
#     Step - The step button will move the debugger into function call.
#     Over - The Over button will quickly execute the function call without stepping into it.
#     In   - The In button will quickly execute the function call by steppign into it.
#     Out  - The out button will quicklu execute the rest of the code until it steps out of the function it currently is in.

# %% [markdown]
# # 10.After you click Continue, when will the debugger stop ?

# %% [markdown]
# Ans:
#
#     After click continue, the debugger will stop when it has reached the end of the program or line with a breakpoint.

# %% [markdown]
# # 11. What is the concept of a breakpoint?

# %% [markdown]
# Ans:
#
#      A breakpoint is a setting on a line of code that causes the debugger to pause when the program execution reachesthe        line.
