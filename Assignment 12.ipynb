# %% [markdown]
# # 1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?

# %% [markdown]
# Ans:-
#
#     Read-binary ('rb') for PdfFileReader() and write-binary ('wb') for PdfFileWriter.

# %% [markdown]
# # 2. From a PdfFileReader object, how do you get a Page object for page 5?

# %% [markdown]
# Ans:-
#
#     Calling getPage(4) will return a Page obejct of the book, since page 0 is the first page.

# %% [markdown]
# # 3. What PdfFileReader variable stores the number of pages in the PDF document?

# %% [markdown]
# Ans:-
#
#     The numPages variables stored an integer of the number of pages in the PdfFileReader object.

# %% [markdown]
# # 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?

# %% [markdown]
# Ans:-
#
#     Call decrypt('swordfish')

# %% [markdown]
# # 5. What methods do you use to rotate a page?

# %% [markdown]
# Ans:-
#
#      While viewing page, press the "Ctrl+Shift+L" keys or "Ctrl+Shift+R" keys to rotate the current page to the left or          right.

# %% [markdown]
# # 6. What is the difference between a Run object and a Paragraph object?

# %% [markdown]
# Ans:-
#
#     A document contains multiple paragraphs. A paragraphs begin on a new line and contains multiple runs.
#     Runs are contigues groups of character within a paragraph.

# %% [markdown]
# # 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?

# %% [markdown]
# Ans:-
#
#        Use doc.paragraphs.

# %% [markdown]
# # 8. What type of object has bold, underline, italic, strike, and outline variables?

# %% [markdown]
# Ans:-
#
#     A run object has these variables (not a paragraphs)

# %% [markdown]
# # 9. What is the difference between False, True, and None for the bold variable?

# %% [markdown]
# Ans:
#
#     True always make the Run object bolded False makes it always not bolded.
#
#     None will make the Run object just use the Style's bold setting.

# %% [markdown]
# # 10. How do you create a Document object for a new Word document?

# %% [markdown]
# Ans:-
#
#     Call the docx.Document() function.

# %% [markdown]
# # 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?

# %% [markdown]
# Ans:-
#
#     doc.add_paragraph("Hello there!")

# %% [markdown]
# # 12. What integers represent the levels of headings available in Word documents?

# %% [markdown]
# Ans:-
#
#     The integers 0,1,2,3 and 4.
